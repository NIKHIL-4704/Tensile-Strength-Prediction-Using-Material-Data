# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
Dataset=pd.read_csv(r"C:\Users\nikhi\OneDrive\Desktop\Prediction _of _Tensile-strength\material_properties.csv")
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Material              200 non-null    object
#  1   Density               170 non-null    float64
#  2   Thermal_Conductivity  180 non-null    float64
#  3   Youngs_Modulus        165 non-null    float64
#  4   Tensile_Strength      178 non-null    float64
#  5   Elongation            178 non-null    float64
#  6   Hardness              170 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 11.1+ KB

# %%
# Apply Label Encoding
label_encoder = LabelEncoder()
Dataset["Material_Label"] = label_encoder.fit_transform(Dataset["Material"])

# %%
print(Dataset[["Material", "Material_Label"]].head(10))
# Out:
#              Material  Material_Label
# 0            Aluminum               2
# 1             Acrylic               0
# 2         Polysulfone              68
# 3        Spring Steel              80
# 4     Silicon Nitride              78
# 5         Polysulfone              68
# 6               Glass              37
# 7              Bronze              11
# 8      Chromoly Steel              19
# 9  High Entropy Alloy              43

# %%
Dataset.head(10)
# Out:
#              Material      Density  Thermal_Conductivity  Youngs_Modulus  \
# 0            Aluminum  8989.129447             95.837383      196.120774
# 1             Acrylic  7146.454919            111.456335       71.909094
# 2         Polysulfone  8830.812776             97.871703             NaN
# 3        Spring Steel  8964.408592             87.443499      192.062181
# 4     Silicon Nitride  8980.192336                   NaN      199.559891
# 5         Polysulfone  7125.482469            118.796698       78.238387
# 6               Glass  8450.415856            108.773993       92.898877
# 7              Bronze  8948.375602            406.978040      106.300698
# 8      Chromoly Steel  8812.779065             95.632277      193.430376
# 9  High Entropy Alloy  8981.027774                   NaN      110.087722
#
#    Tensile_Strength  Elongation    Hardness  Material_Label
# 0        427.877131   29.206045  227.252472               2
# ...
